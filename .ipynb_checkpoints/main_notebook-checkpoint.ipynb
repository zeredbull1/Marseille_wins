# %%
import pandas as pd
import numpy as np

# FTHG and HG = Full Time Home Team Goals
# FTAG and AG = Full Time Away Team Goals
# FTR and Res = Full Time Result (H=Home Win, D=Draw, A=Away Win)

fields = ["Date", "HomeTeam", "AwayTeam", "FTHG", "FTAG", "FTR"]

df = pd.read_csv("data/Ligue1_game_stats.csv", usecols = fields)

df.head()
# Out:
#          Date HomeTeam   AwayTeam  FTHG  FTAG FTR
# 0  15/08/2025   Rennes  Marseille     1     0   H
# 1  16/08/2025     Lens       Lyon     0     1   A
# 2  16/08/2025   Monaco   Le Havre     3     1   H
# 3  16/08/2025     Nice   Toulouse     0     1   A
# 4  17/08/2025    Brest      Lille     3     3   D

# %%
# Dataset with only Marseille games

df_om_games = df[(df["HomeTeam"] == "Marseille") | (df["AwayTeam"] == "Marseille")].copy()




df_om_games.head()

df_om_games["OM_goals_scored"] = np.where(df_om_games['HomeTeam'] == 'Marseille', df_om_games["FTHG"], df_om_games["FTAG"])
df_om_games["OM_goals_conceded"] = np.where(df_om_games['HomeTeam'] == 'Marseille', df_om_games["FTAG"], df_om_games["FTHG"])
df_om_games["is_OM_win"] = np.where(df_om_games['HomeTeam'] == 'Marseille', df_om_games["FTR"] == "H", df_om_games["FTR"] == "A")
df_om_games["is_Draw"] = df_om_games["FTR"] == "D"


df_om_games.head(10)

df_om_games = df_om_games.assign(goals_scored_last_3_games=lambda d: d["OM_goals_scored"].rolling(3).sum().shift())
df_om_games = df_om_games.assign(goals_conceded_last_3_games=lambda d: d["OM_goals_conceded"].rolling(3).sum().shift())

df_om_games
# Out:
#           Date    HomeTeam   AwayTeam  FTHG  FTAG FTR  OM_goals  is_OM_win  \
# 0   15/08/2025      Rennes  Marseille     1     0   H         0      False
# 10  23/08/2025   Marseille   Paris FC     5     2   H         5       True
# 26  31/08/2025        Lyon  Marseille     1     0   H         0      False
# 27  12/09/2025   Marseille    Lorient     4     0   H         4       True
# 44  22/09/2025   Marseille   Paris SG     1     0   H         1       True
# 45  26/09/2025  Strasbourg  Marseille     1     2   A         2       True
# 55  04/10/2025        Metz  Marseille     0     3   A         3       True
# 66  18/10/2025   Marseille   Le Havre     6     2   H         6       True
# 75  25/10/2025        Lens  Marseille     2     1   H         1      False
# 85  29/10/2025   Marseille     Angers     2     2   D         2      False
# 92  01/11/2025     Auxerre  Marseille     0     1   A         1       True
#
#     OM_goals_scored  OM_goals_conceded  is_Draw  goals_scored_last_3_games  \
# 0                 0                  1    False                        NaN
# 10                5                  2    False                        NaN
# 26                0                  1    False                        NaN
# 27                4                  0    False                        5.0
# 44                1                  0    False                        9.0
# 45                2                  1    False                        5.0
# 55                3                  0    False                        7.0
# 66                6                  2    False                        6.0
# 75                1                  2    False                       11.0
# 85                2                  2     True                       10.0
# 92                1                  0    False                        9.0
#
#     goals_conceded_last_3_games
# 0                           NaN
# 10                          NaN
# 26                          NaN
# 27                          4.0
# 44                          3.0
# 45                          1.0
# 55                          1.0
# 66                          1.0
# 75                          3.0
# 85                          4.0
# 92                          6.0

# %%
# TODO, add number of rest days before game - pour ça il va falloir aussi rajouter les matchs joués en champions league.
